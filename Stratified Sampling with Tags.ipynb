# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('movies.csv')
MoviesG=df.movieId.unique()

# %%
df_tag = pd.read_csv('tags.csv')
MoviesT=df_tag.movieId.unique()

# %%
from collections import defaultdict
tagDict = defaultdict(list)

for index,row in df_tag.iterrows():
    tagDict[row['movieId']].append(row['tag'])

#print tag dictionary (size-19545)
for key, value in tagDict.iteritems() :
    print key, value
# Out:
# 1 ['Watched', 'computer animation', 'Disney animated feature', 'Pixar animation', 'T\xc3\x83\xc2\xa9a Leoni does not star in this movie', 'Pixar', 'animation', 'family', 'Tom Hanks', 'Pixar', 'witty', 'Pixar', 'adventure', 'animated', 'animation', 'clever', 'comedy', 'computer animation', 'family', 'fantasy', 'Tom Hanks', 'bright', 'DARING RESCUES', 'fanciful', 'HEROIC MISSION', 'humorous', 'light', 'rousing', 'TOYS COME TO LIFE', 'UNLIKELY FRIENDSHIPS', 'warm', 'witty', 'animation', 'humorous', 'Pixar', 'time travel', 'Pixar', 'Pixar animation', 'animation', 'kids movie', 'Pixar', 'Pixar', 'Pixar', 'witty', 'Disney', 'Tim Allen', 'time travel', 'action figure', 'action figures', 'Buzz Lightyear', 'CG animation', 'toy', 'toys', 'Woody', 'animation', 'Pixar', 'animation', 'Disney', 'villian hurts toys', 'pixar', 'animation', 'disney', 'fantasy', 'Pixar', 'animation', 'pixar', 'children', '\xc3\xa9\xcb\x9c\xc2\xae\xc3\xa4\xc2\xb8\xe2\x82\xac\xc3\xa9\xc2\xb8\xc2\xa3', 'animation', 'comp
# ...

# %%
Genre = ["Action", "Adventure", "Animation", "Children", "Comedy", "Crime", "Documentary", "Drama", "Fantasy", 
         "Film-Noir", "Horror", "Musical", "Mystery", "Romance", "Sci-Fi", "Thriller", "War", "Western" ]

# %%
fullGenDict = {}
for index, row in df.iterrows():
    string = row['genres'].split("|")
    fullGenDict[row['movieId']]=string

#print complete genre dictionary
for key, value in fullGenDict.iteritems() :
    print key, value
# Out:
# 131072 ['Comedy']
# 1 ['Adventure', 'Animation', 'Children', 'Comedy', 'Fantasy']
# 2 ['Adventure', 'Children', 'Fantasy']
# 3 ['Comedy', 'Romance']
# 4 ['Comedy', 'Drama', 'Romance']
# 5 ['Comedy']
# 6 ['Action', 'Crime', 'Thriller']
# 7 ['Comedy', 'Romance']
# 8 ['Adventure', 'Children']
# 9 ['Action']
# 10 ['Action', 'Adventure', 'Thriller']
# 11 ['Comedy', 'Drama', 'Romance']
# 12 ['Comedy', 'Horror']
# 13 ['Adventure', 'Animation', 'Children']
# 14 ['Drama']
# 15 ['Action', 'Adventure', 'Romance']
# 16 ['Crime', 'Drama']
# 17 ['Drama', 'Romance']
# 18 ['Comedy']
# 19 ['Comedy']
# 20 ['Action', 'Comedy', 'Crime', 'Drama', 'Thriller']
# 21 ['Comedy', 'Crime', 'Thriller']
# 22 ['Crime', 'Drama', 'Horror', 'Mystery', 'Thriller']
# 23 ['Action', 'Crime', 'Thriller']
# 24 ['Drama', 'Sci-Fi']
# 25 ['Drama', 'Romance']
# 26 ['Drama']
# 27 ['Children', 'Drama']
# 28 ['Drama', 'Romance']
# 29 ['Adventure', 'Drama', 'Fantasy', 'Mystery', 'Sci-Fi']
# 30 ['Crime', 'Drama']
# 31 ['Drama']
# ...

# %%
#only genre dictionary for only movies for which tagging data is abvailable. 
genDict={}
for i in MoviesT:
    if i in MoviesG:
        genDict[i]=fullGenDict.get(i)
'''
#logic for removing genre other than 18 genres.
for key, value in genDict.iteritems():
    for i in value:
        if i not in Genre:
            value.remove(i)
        genDict[key]=value
'''        
        
#print genre dictionry (size - 19545)         
for key, value in genDict.iteritems():
    print key, value
# Out:
# 1 ['Adventure', 'Animation', 'Children', 'Comedy', 'Fantasy']
# 2 ['Adventure', 'Children', 'Fantasy']
# 3 ['Comedy', 'Romance']
# 4 ['Comedy', 'Drama', 'Romance']
# 5 ['Comedy']
# 6 ['Action', 'Crime', 'Thriller']
# 7 ['Comedy', 'Romance']
# 8 ['Adventure', 'Children']
# 9 ['Action']
# 10 ['Action', 'Adventure', 'Thriller']
# 11 ['Comedy', 'Drama', 'Romance']
# 12 ['Comedy', 'Horror']
# 32781 ['Drama']
# 14 ['Drama']
# 15 ['Action', 'Adventure', 'Romance']
# 16 ['Crime', 'Drama']
# 17 ['Drama', 'Romance']
# 18 ['Comedy']
# 19 ['Comedy']
# 20 ['Action', 'Comedy', 'Crime', 'Drama', 'Thriller']
# 21 ['Comedy', 'Crime', 'Thriller']
# 22 ['Crime', 'Drama', 'Horror', 'Mystery', 'Thriller']
# 23 ['Action', 'Crime', 'Thriller']
# 24 ['Drama', 'Sci-Fi']
# 25 ['Drama', 'Romance']
# 26 ['Drama']
# 27 ['Children', 'Drama']
# 28 ['Drama', 'Romance']
# 29 ['Adventure', 'Drama', 'Fantasy', 'Mystery', 'Sci-Fi']
# 30 ['Crime', 'Drama']
# 31 ['Drama']
# 32 ['Mystery', 'Sci-Fi', 'Thriller']
# ...

# %%
#tagDict, genDict
print len(tagDict)
print len(genDict)

df_TG = pd.DataFrame(columns=['movieId','genre','tag'])
i=0
for key, value in genDict.iteritems():
    tag=tagDict.get(key)
    df_TG.loc[i] = [key, value, tag]
    i=i+1
print i
df_TG.head(50)
# Out:
# 19545
# 19545
# 19545
#    movieId                                              genre  \
# 0        1  [Adventure, Animation, Children, Comedy, Fantasy]
# 1        2                     [Adventure, Children, Fantasy]
# 2        3                                  [Comedy, Romance]
# 3        4                           [Comedy, Drama, Romance]
# 4        5                                           [Comedy]
# 5        6                          [Action, Crime, Thriller]
# 6        7                                  [Comedy, Romance]
# 7        8                              [Adventure, Children]
# 8        9                                           [Action]
# 9       10                      [Action, Adventure, Thriller]
# 10      11                           [Comedy, Drama, Romance]
# 11      12                                   [Comedy, Horror]
# 12   32781                                            [Drama]
# 13      14                                            [Drama]
# ...

# %%
df_TG.to_csv('gen_tag.csv', sep=',', encoding='utf-8')
